# %%
import ee

# %%
ee.Authenticate()
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=S6QlGn-0NxpF2bMsNe9qm_aEkds0qQbvzhXk8qDe6iM&tc=uvdsx24NSzFwsaByXnH9XcPsXtNPcI2Fgbs6zoJTBQg&cc=40AwxfCg3V-ooaI513OuhevCXzib4YNLYyJPjxNIOxg>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=S6QlGn-0NxpF2bMsNe9qm_aEkds0qQbvzhXk8qDe6iM&tc=uvdsx24NSzFwsaByXnH9XcPsXtNPcI2Fgbs6zoJTBQg&cc=40AwxfCg3V-ooaI513OuhevCXzib4YNLYyJPjxNIOxg</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
ee.Initialize()

# %% [markdown]
# earth engine y autentificación

# %%
import rasterio

# %%
import rasterio as rio
import folium
from pyproj import Transformer

# %%
pwd()
# Out:
# '/Users/gabrielalvarez/Dropbox/pendrives/Tercera_region/Imagen_landsat_afta'

# %%
from pyproj import Transformer

# %%
## LC08 RGB Image
in_path ='*.tif'

dst_crs = 'EPSG:4326'

# %%
import rasterio.warp

# %%
dataset_area = ee.FeatureCollection("users/galvarez59/aguas_calientes_area")

# %%
import rasterio
from matplotlib import pyplot

tif_file = '/Users/gabrielalvarez/Dropbox/pendrives/Tercera_region/Imagen_landsat_afta/SP27GTIF.TIFf'
src = rasterio.open(tif_file)
pyplot.imshow(src.read(1), cmap='pink')
pyplot.show = lambda : None  # prevents showing during doctests
pyplot.show()

# %%
pwd()
# Out:
# '/Users/gabrielalvarez/Dropbox/pendrives/Tercera_region/Imagen_landsat_afta'

# %%
mymap = folium.Map(
    location=[41.0, -84],
    zoom_start=8,
    tiles='OpenStreetMap')
mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import rasterio as rio
import folium
from pyproj import Transformer 

## LC08 RGB Image
in_path = tif_file

dst_crs = 'EPSG:4326'

with rio.open(in_path) as src:
    
    img = src.read()
        
    src_crs = src.crs['init'].upper()
    min_lon, min_lat, max_lon, max_lat = src.bounds
    
## Conversion from UTM to WGS84 CRS
bounds_orig = [[min_lat, min_lon], [max_lat, max_lon]]

bounds_fin = []
 
for item in bounds_orig:   
    #converting to lat/lon
    lat = item[0]
    lon = item[1]
    
    proj = Transformer.from_crs(int(src_crs.split(":")[1]), int(dst_crs.split(":")[1]), always_xy=True)

    lon_n, lat_n = proj.transform(lon, lat)
    
    bounds_fin.append([lat_n, lon_n])

# Finding the centre latitude & longitude    
centre_lon = bounds_fin[0][1] + (bounds_fin[1][1] - bounds_fin[0][1])/2
centre_lat = bounds_fin[0][0] + (bounds_fin[1][0] - bounds_fin[0][0])/2

m = folium.Map(location=[centre_lat, centre_lon],
                   tiles='Stamen Terrain', zoom_start = 10)

# Overlay raster (RGB) called img using add_child() function (opacity and bounding box set)
m.add_child(folium.raster_layers.ImageOverlay(img.transpose(1, 2, 0), opacity=.7, 
                                 bounds = bounds_fin))

# Display map 
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import math
import matplotlib.pyplot as plt

import geopandas as gpd
import pandas as pd
import rasterio
import rasterio.plot
import shapely
import unrasterize
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Untitled-2.ipynb Celda 18 in <cell line: 9>()
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X30sdW50aXRsZWQ%3D?line=6'>7</a> import rasterio.plot
#       <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X30sdW50aXRsZWQ%3D?line=7'>8</a> import shapely
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X30sdW50aXRsZWQ%3D?line=8'>9</a> import unrasterize
#
# ModuleNotFoundError: No module named 'unrasterize'

# %%
imageRGB= imageRGB.getTrumbURL({'region': dataset.geometry(),'dimensions':500,'format':extension})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-2.ipynb Celda 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-2.ipynb?jupyter-notebook#X23sdW50aXRsZWQ%3D?line=0'>1</a> imageRGB= imageRGB.getTrumbURL({'region': dataset.geometry(),'dimensions':500,'format':extension})
#
# NameError: name 'imageRGB' is not defined
